# %% [markdown]
# # 批量归一化

# %% [markdown]
# ![image.png](attachment:86662892-1494-45f8-b0d2-471c7d85f88b.png)
#
# ![image.png](attachment:5399cb63-52ae-4931-95e7-9a55c71230d7.png)
#
# ![image.png](attachment:fb96f78a-7a0c-4339-808d-f47873fab004.png)
#
# ![image.png](attachment:1b1e53e0-9729-4113-9933-fc1d2e868049.png)
#
# ![image.png](attachment:df9fbfc7-29d5-4cdf-bc7b-b06be7d857a3.png)

# %% [markdown]
# ## 从零实现

# %%
import torch
from torch import nn
from d2l import as d2l

def batch_norm(X, gamma, beta, moving_mean, moving_var, eps, momentum):
